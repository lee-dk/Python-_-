# %%
from selenium import webdriver
import pandas as pd


x = ['127.151700', '126.862524', '126.979271', '127.092537', '126.994690', '127.044248', '127.104944', '127.127259', '127.055595', '126.973269', '126.954635', '127.084621', '126.806736', '127.125388', '126.894004', '127.121997']
y = ['37.557347', '37.542747', '37.488853', '37.502862', '37.520521', '37.546461', '37.489031', '37.551953', '37.564030', '37.521552', '37.526423', '37.483657', '37.566860', '37.543610', '37.536550', '37.538177']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX='
url_startY = '&startY='
url_endX = '&endX='
url_endY = '&endY='
df = pd.DataFrame(columns=['start_place', 'end_place', 'travelTime'])
for n in range(0,6) :
    url = url_startX + x[n] + url_startY + y[n] + url_endX + x[n+1] + url_endY + y[n+1]
    driver.get(url)
    driver.implicitly_wait(5)
    start_place = driver.find_element_by_css_selector('#folder4 > div.opened > div:nth-child(2) > span:nth-child(2)').text

    end_place = driver.find_element_by_css_selector("#folder4 > div.opened > div:nth-child(8) > span:nth-child(2)").text

    travelTime = driver.find_element_by_css_selector('#folder3 > div.opened > div:nth-child(3) > span').text
    # folder3 > div.opened > div:nth-child(4) > span:nth-child(2)
    driver.implicitly_wait(8)

    print("출발 : ", start_place)
    print("도착 : ", end_place)
    print("이동시간 : ", travelTime)

    driver.implicitly_wait(5)
#driver.quit()
'''
with open('C:/Temp/TravelTime.csv', "wt", encoding="utf-8") as f:
    f.write('start_place,end_place,travelTime\n')
    for i in range(len(start_place)):
        f.write('"' + start_place[i] + '",' + end_place[i] + '",' + travelTime[i] + '\n')
'''

# %% [markdown]
# # 강남역 출발(오후 6시)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 상계8동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[0] + url_endY + y[0]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 등촌2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[1] + url_endY + y[1]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 암사2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[2] + url_endY + y[2]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 이촌2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[3] + url_endY + y[3]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 풍납1동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[4] + url_endY + y[4]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 자양2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[5] + url_endY + y[5]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 잠실4동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[6] + url_endY + y[6]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 면목2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[7] + url_endY + y[7]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 수서동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[8] + url_endY + y[8]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 신정4동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[9] + url_endY + y[9]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 천호1동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[10] + url_endY + y[10]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 서빙고동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[11] + url_endY + y[11]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 송파1동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[12] + url_endY + y[12]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#강남역 출발 - 개봉2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=127.027977657727'
url_startY = '&startY=37.4980854411503'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[13] + url_endY + y[13]
driver.get(url)

# %% [markdown]
# # 시청역 출발(오후6시)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 상계8동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[0] + url_endY + y[0]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 등촌2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[1] + url_endY + y[1]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 암사2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[2] + url_endY + y[2]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 이촌2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[3] + url_endY + y[3]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 풍납1동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[4] + url_endY + y[4]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 자양2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[5] + url_endY + y[5]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 잠실4동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[6] + url_endY + y[6]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 면목2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[7] + url_endY + y[7]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 수서동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[8] + url_endY + y[8]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 신정4동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[9] + url_endY + y[9]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 천호1동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[10] + url_endY + y[10]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 서빙고동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[11] + url_endY + y[11]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 송파1동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[12] + url_endY + y[12]
driver.get(url)

# %%
from selenium import webdriver

x = ['127.051581', '126.862524', '127.127259', '126.954635', '127.121997', '127.084334', '127.112268', '127.079023', '127.104944', '126.855867', '127.136616', '126.994690', '127.109387', '126.855406']
y = ['37.666886', '37.542747', '37.551953', '37.526423', '37.538177', '37.529217', '37.520243', '37.590064', '37.489031', '37.525109', '37.545631', '37.520521', '37.506954', '37.493654']

driver = webdriver.Chrome('C:/Temp/chromedriver.exe')
driver.implicitly_wait(3)

#시청역 출발 - 개봉2동 도착
url_startX = 'http://ws.bus.go.kr/api/rest/pathinfo/getPathInfoByBusNSub?ServiceKey=MT9k5VcAGch1xQwYHcvv1ej9TCzetVpOFC3ikeBe44U2S11WVLlIgwMvCEbKvoX1zqCgJ58UcWwtiLENWlnzdA%3D%3D&startX=126.977181235023'
url_startY = '&startY=37.5653372841193'
url_endX = '&endX='
url_endY = '&endY='
url = url_startX + url_startY + url_endX + x[13] + url_endY + y[13]
driver.get(url)
